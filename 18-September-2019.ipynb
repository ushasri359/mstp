# %% [markdown]
# ### Series,Dataframes continution

# %%
import pandas as pd

# %%
original_sports=pd.Series({'Archery':"Bhutan",
                  'Golf':"Scotlad",
                  'Sumo':"Japan",
                  'Taekwondo':"South Korea"})
cricket_loving_countries=pd.Series(['Australia',
                                    'Barbados',
                                    'Pakistan',
                                    'England'],
                                  index=['Cricket',
                                         'Cricket',
                                         'Cricket',
                                         'Cricket'])
all_countries=original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf             Scotlad
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
cricket_loving_countries
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf             Scotlad
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
all_countries.loc['Cricket']
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
u=all_countries.loc['Cricket']
u.iloc[0]='australia'
u
# Out:
# Cricket    australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
all_countries[4]='australia'
all_countries
# Out:
# Archery           Bhutan
# Golf             Scotlad
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %% [markdown]
# ### DataFrame

# %%
purchase_1=pd.Series({'Name':'Chris',
                       'Item Purchased':'Dog Food',
                       'Cost':22.50})
purchase_3=pd.Series({'Name':'Vinod',
                       'Item Purchased':'Bird Seed',
                       'Cost':5.00})
purchase_2=pd.Series({'Name':'Kevyn',
                       'Item Purchased':'Kitty Letter',
                       'Cost':2.50})
df=pd.DataFrame([purchase_1,purchase_2,purchase_3],index=['Store 1','Store 3','Store 3'])
df.head()
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 3  Kevyn   Kitty Letter   2.5
# Store 3  Vinod      Bird Seed   5.0

# %%
df.loc['Store 1']
# Out:
# Name                 Chris
# Item Purchased    Dog Food
# Cost                  22.5
# Name: Store 1, dtype: object

# %%
type(df.loc['Store 1'])
# Out:
# pandas.core.series.Series

# %%
df.loc['Store 3','Cost']
# Out:
# Store 3    2.5
# Store 3    5.0
# Name: Cost, dtype: float64

# %%
type(df.loc['Store 3'])
# Out:
# pandas.core.frame.DataFrame

# %%
df.T
# Out:
#                  Store 1       Store 3    Store 3
# Name               Chris         Kevyn      Vinod
# Item Purchased  Dog Food  Kitty Letter  Bird Seed
# Cost                22.5           2.5          5

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 3  Kevyn   Kitty Letter   2.5
# Store 3  Vinod      Bird Seed   5.0

# %%
df.T.loc['Cost']
# Out:
# Store 1    22.5
# Store 3     2.5
# Store 3       5
# Name: Cost, dtype: object

# %%
df.T.loc['Item Purchased']
# Out:
# Store 1        Dog Food
# Store 3    Kitty Letter
# Store 3       Bird Seed
# Name: Item Purchased, dtype: object

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 3  Kevyn   Kitty Letter   2.5
# Store 3  Vinod      Bird Seed   5.0

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 3     2.5
# Store 3     5.0
# Name: Cost, dtype: float64

# %%
df.loc['Store 3']['Cost']
# Out:
# Store 3    2.5
# Store 3    5.0
# Name: Cost, dtype: float64

# %%
df.loc[:,['Name','Cost']]
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 3  Kevyn   2.5
# Store 3  Vinod   5.0

# %%
df.drop('Store 3')
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 3  Kevyn   Kitty Letter   2.5
# Store 3  Vinod      Bird Seed   5.0

# %%
copy_df=df.copy()
copy_df=copy_df.drop('Store 1')
copy_df
# Out:
#           Name Item Purchased  Cost
# Store 3  Kevyn   Kitty Letter   2.5
# Store 3  Vinod      Bird Seed   5.0

# %%
copy_df=df.copy()
copy_df=copy_df.drop('Store 1')
copy_df
# Out:
#           Name Item Purchased  Cost
# Store 3  Kevyn   Kitty Letter   2.5
# Store 3  Vinod      Bird Seed   5.0

# %%
copy_df=df.copy()
copy_df=copy_df.drop('Store 1',inplace=True)
copy_df

# %%
del copy_df['Name']
copy_df
# Out:
#         Item Purchased  Cost
# Store 3   Kitty Letter   2.5
# Store 3      Bird Seed   5.0

# %%
df['Location']=None
df
# Out:
#           Name Item Purchased  Cost Location   State
# Store 1  Chris       Dog Food  22.5     None  Mumbai
# Store 3  Kevyn   Kitty Letter   2.5     None      TG
# Store 3  Vinod      Bird Seed   5.0     None   Delhi

# %%
df['State']=['Ap','TG','Delhi']

# %%
df
# Out:
#           Name Item Purchased  Cost Location  State
# Store 1  Chris       Dog Food  22.5     None     Ap
# Store 3  Kevyn   Kitty Letter   2.5     None     TG
# Store 3  Vinod      Bird Seed   5.0     None  Delhi

# %%
df.loc['Store 1','State']='Mumbai'

# %%
df
# Out:
#           Name Item Purchased  Cost Location   State
# Store 1  Chris       Dog Food  22.5     None  Mumbai
# Store 3  Kevyn   Kitty Letter   2.5     None      TG
# Store 3  Vinod      Bird Seed   5.0     None   Delhi

# %%
df['State']['Store 1']='AP'
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           Name Item Purchased  Cost Location  State
# Store 1  Chris       Dog Food  22.5     None     AP
# Store 3  Kevyn   Kitty Letter   2.5     None     TG
# Store 3  Vinod      Bird Seed   5.0     None  Delhi

# %% [markdown]
# ### DataFrame Indexing and Loading

# %%
df
# Out:
#           Name Item Purchased  Cost Location  State
# Store 1  Chris       Dog Food  22.5     None     AP
# Store 3  Kevyn   Kitty Letter   2.5     None     TG
# Store 3  Vinod      Bird Seed   5.0     None  Delhi

# %%
costs=df['Cost']
costs
# Out:
# Store 1    22.5
# Store 3     2.5
# Store 3     5.0
# Name: Cost, dtype: float64

# %%
costs+=2
costs
# Out:
# Store 1    24.5
# Store 3     4.5
# Store 3     7.0
# Name: Cost, dtype: float64

# %%
df
# Out:
#           Name Item Purchased  Cost Location  State
# Store 1  Chris       Dog Food  24.5     None     AP
# Store 3  Kevyn   Kitty Letter   4.5     None     TG
# Store 3  Vinod      Bird Seed   7.0     None  Delhi

# %%
df=pd.read_csv('olympics.csv')
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df=pd.read_csv('olympics.csv',index_col=0,skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %% [markdown]
# ## Querying a DataFrame

# %%
df['Gold']
# Out:
# Afghanistan (AFG)                                  0
# Algeria (ALG)                                      5
# Argentina (ARG)                                   18
# Armenia (ARM)                                      1
# Australasia (ANZ) [ANZ]                            3
# Australia (AUS) [AUS] [Z]                        139
# Austria (AUT)                                     18
# Azerbaijan (AZE)                                   6
# Bahamas (BAH)                                      5
# Bahrain (BRN)                                      0
# Barbados (BAR) [BAR]                               0
# Belarus (BLR)                                     12
# Belgium (BEL)                                     37
# Bermuda (BER)                                      0
# Bohemia (BOH) [BOH] [Z]                            0
# Botswana (BOT)                                     0
# Brazil (BRA)                                      23
# British West Indies (BWI) [BWI]                    0
# ...

# %% [markdown]
# ### Write the logic to get the countries who got above 5 gold medals

# %%
df['Gold']>=5
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                   False
# Australasia (ANZ) [ANZ]                         False
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                 True
# Bahamas (BAH)                                    True
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                    True
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                     True
# ...

# %% [markdown]
# #### 1)How many countries won atleast 1 gold medal in summer?

# %%
only_gold=df.where(df['Gold']>0)
only_gold
# Out:
#                                               # Summer    Gold  Silver  \
# Afghanistan (AFG)                                  NaN     NaN     NaN
# Algeria (ALG)                                     12.0     5.0     2.0
# Argentina (ARG)                                   23.0    18.0    24.0
# Armenia (ARM)                                      5.0     1.0     2.0
# Australasia (ANZ) [ANZ]                            2.0     3.0     4.0
# Australia (AUS) [AUS] [Z]                         25.0   139.0   152.0
# Austria (AUT)                                     26.0    18.0    33.0
# Azerbaijan (AZE)                                   5.0     6.0     5.0
# Bahamas (BAH)                                     15.0     5.0     2.0
# Bahrain (BRN)                                      NaN     NaN     NaN
# Barbados (BAR) [BAR]                               NaN     NaN     NaN
# Belarus (BLR)                                      5.0    12.0    24.0
# ...

# %%
only_gold.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
only_gold['Gold'].count()
# Out:
# 101

# %%
df['Gold'].count()
# Out:
# 147

# %% [markdown]
# #### 2)How many countries get atleast 1 gold medal in combined?

# %%
only_gold=df.where(df['Gold.2']>0)
only_gold.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
only_gold['Gold.2'].count()
# Out:
# 101

# %%
df['country']=df.index
df.set_index('Gold').head()
# Out:
#       # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 0           13       0       2      2         0       0         0         0
# 5           12       2       8     15         3       0         0         0
# 18          23      24      28     70        18       0         0         0
# 1            5       2       9     12         6       0         0         0
# 3            2       4       5     12         0       0         0         0
#
#       Total.1  # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# Gold
# 0           0       13       0         0         2               2
# 5           0       15       5         2         8              15
# 18          0       41      18        24        28              70
# 1           0       11       1         2         9              12
# 3           0        2       3         4         5              12
#
#                       country
# Gold
# 0           Afghanistan (AFG)
# ...

# %%
df=df.reset_index()
df.head()
# Out:
#                      index  # Summer  Gold  Silver  Bronze  Total  # Winter  \
# 0        Afghanistan (AFG)        13     0       0       2      2         0
# 1            Algeria (ALG)        12     5       2       8     15         3
# 2          Argentina (ARG)        23    18      24      28     70        18
# 3            Armenia (ARM)         5     1       2       9     12         6
# 4  Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#    Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# 0       0         0         0        0       13       0         0         2
# 1       0         0         0        0       15       5         2         8
# 2       0         0         0        0       41      18        24        28
# 3       0         0         0        0       11       1         2         9
# 4       0         0         0        0        2       3         4         5
#
#    Combined total                  country
# ...

# %%
df=pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df=df.set_index(['STNAME','CTYNAME'])
df.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Alabama             40       3         6      1       0
#         Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama               4779736            4780127          4785161
#         Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
df.loc['Alabama','Autauga County']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# STNAME  CTYNAME                                           ...
# Alabama Autauga County            55253            55175  ...
#
#                         RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME  CTYNAME
# Alabama Autauga County          7.242091         -2.915927         -3.012349
#
#                         RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  \
# STNAME  CTYNAME
# ...

# %%
df.loc[('Michigan','Washtenaw County')]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME   CTYNAME
# Michigan Washtenaw County      50       2         3     26     161
#
#                            CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County         344791             345066           345563
#
#                            POPESTIMATE2011  POPESTIMATE2012  ...  \
# STNAME   CTYNAME                                             ...
# Michigan Washtenaw County           349048           351213  ...
#
#                            RDOMESTICMIG2011  RDOMESTICMIG2012  \
# STNAME   CTYNAME
# Michigan Washtenaw County          0.129569         -4.309822
#
#                            RDOMESTICMIG2013  RDOMESTICMIG2014  \
# STNAME   CTYNAME
# ...

# %%
df.loc[[('Michigan','Washtenaw County'),
       ('Michigan','Wayne County')]]
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME   CTYNAME
# Michigan Washtenaw County      50       2         3     26     161
#          Wayne County          50       2         3     26     163
#
#                            CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County         344791             345066           345563
#          Wayne County            1820584            1820641          1815199
#
#                            POPESTIMATE2011  POPESTIMATE2012  ...  \
# STNAME   CTYNAME                                             ...
# Michigan Washtenaw County           349048           351213  ...
#          Wayne County              1801273          1792514  ...
#
#                            RDOMESTICMIG2011  RDOMESTICMIG2012  \
# STNAME   CTYNAME
# Michigan Washtenaw County          0.129569         -4.309822
#          Wayne County            -13.340073        -10.271616
#
# ...

# %%
df=df[df['SUMLEV']==50]
df.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#         Blount County       50       3         6      1       9
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#         Blount County           57322              57322            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
df.loc['Alabama','Autauga County']
# Out:
# SUMLEV                      50.000000
# REGION                       3.000000
# DIVISION                     6.000000
# STATE                        1.000000
# COUNTY                       1.000000
# CENSUS2010POP            54571.000000
# ESTIMATESBASE2010        54571.000000
# POPESTIMATE2010          54660.000000
# POPESTIMATE2011          55253.000000
# POPESTIMATE2012          55175.000000
# POPESTIMATE2013          55038.000000
# POPESTIMATE2014          55290.000000
# POPESTIMATE2015          55347.000000
# NPOPCHG_2010                89.000000
# NPOPCHG_2011               593.000000
# NPOPCHG_2012               -78.000000
# NPOPCHG_2013              -137.000000
# NPOPCHG_2014               252.000000
# NPOPCHG_2015                57.000000
# BIRTHS2010                 151.000000
# BIRTHS2011                 636.000000
# BIRTHS2012                 615.000000
# BIRTHS2013                 574.000000
# BIRTHS2014                 623.000000
# BIRTHS2015                 600.000000
# ...

# %% [markdown]
# ## Missing Values

# %%
df=pd.read_csv('log.csv')
df
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df.head()
# Out:
#             time       video  playback position paused  volume
# user
# bob   1469977724  intro.html                  1    NaN     NaN
# bob   1469977664  intro.html                  1    NaN     NaN
# bob   1469977634  intro.html                  1    NaN     NaN
# bob   1469977604  intro.html                  1    NaN     NaN
# bob   1469977574  intro.html                  1    NaN     NaN

# %%
df.fillna?

# %%
df=df.set_index('time')
df.head()
# Out:
#               user       video  playback position paused  volume
# time
# 1469974424  cheryl  intro.html                  5  False    10.0
# 1469974454  cheryl  intro.html                  6    NaN     NaN
# 1469974544  cheryl  intro.html                  9    NaN     NaN
# 1469974574  cheryl  intro.html                 10    NaN     NaN
# 1469977514     bob  intro.html                  1    NaN     NaN

# %%
df=df.sort_index()
df.head()
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN

# %%
df=df.reset_index('time')
df=df.set_index(['time','user'])
df
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df.fillna('hi')
# Out:
#                            video  playback position paused volume
# time       user
# 1469974424 cheryl     intro.html                  5  False     10
#            sue     advanced.html                 23  False     10
# 1469974454 cheryl     intro.html                  6     hi     hi
#            sue     advanced.html                 24     hi     hi
# 1469974484 cheryl     intro.html                  7     hi     hi
# 1469974514 cheryl     intro.html                  8     hi     hi
# 1469974524 sue     advanced.html                 25     hi     hi
# 1469974544 cheryl     intro.html                  9     hi     hi
# 1469974554 sue     advanced.html                 26     hi     hi
# 1469974574 cheryl     intro.html                 10     hi     hi
# 1469974604 cheryl     intro.html                 11     hi     hi
# 1469974624 sue     advanced.html                 27     hi     hi
# 1469974634 cheryl     intro.html                 12     hi     hi
# ...

# %%
df.head()
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN

# %%
df.fillna(method='ffill').head()
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0

# %%
df.head()
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN

# %%
df.fillna(method='bfill').head()
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6   True     5.0
#            sue     advanced.html                 24   True     5.0
# 1469974484 cheryl     intro.html                  7   True     5.0
