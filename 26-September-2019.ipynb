# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1,2,2)
linear_data=np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(1,2,1)
plt.plot(left,'-o')

plt.subplot(1,2,2)
plt.plot(right,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(2,2,1)
plt.plot(left,'-o')

plt.subplot(2,2,2)
plt.plot(right,'-o')

plt.subplot(2,2,3)
plt.plot(right,'-o')

plt.subplot(2,2,4)
plt.plot(right,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-o',label='mid1')
plt.legend()
ax2=plt.subplot(1,2,2)
plt.plot([1,2,3],np.array([50,30,40]),'-x',label='mid2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-o')

ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot([1,2,3],np.array([50,30,40]),'-x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### plt.subplot(1,2,1)==plt.subplot(121)

# %%
# create a 3x3 grid of subplots
fig,((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True,sharey=True)
# plot the linear_data on the 5th subplot axes
ax5.plot(linear_data,'--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### bar graph:

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data)) #[0,1,2,3]
plt.bar(xvals,linear_data,width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data)) #[0,1,2,3]
plt.barh(xvals,linear_data,height=0.3)      # barh,height
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>

# %% [markdown]
# ###  Histograms

# %%
marks=[50,60,70,50,50,30,50,70,50]
plt.figure()
plt.hist(marks)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1., 0., 0., 0., 0., 5., 0., 1., 0., 2.]),
#  array([30., 34., 38., 42., 46., 50., 54., 58., 62., 66., 70.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ###  Box and Whisker plots

# %%
height_men_at_20=[4,5,4.5,5,6,7]

# %%
plt.figure()
plt.boxplot(height_men_at_20,whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x267c8f6be80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x267c8f787b8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x267c8f6bd30>],
#  'medians': [<matplotlib.lines.Line2D at 0x267c8f78e48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x267c8f78f28>],
#  'means': []}

# %%
import matplotlib.animation as animation
n=100
x=np.random.randn(n)
def update(curr):
    if curr==n:
        a.event_source.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sampling the normal Distributiion')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a=animation.FuncAnimation(fig,update,interval=100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
